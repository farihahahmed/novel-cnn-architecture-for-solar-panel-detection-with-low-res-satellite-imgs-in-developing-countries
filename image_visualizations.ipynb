# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('/Users/farihahahmed/Desktop/deepsolar/test/1/solar-panels-farms.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (160, 160, 3)

# %%
type(img)
# Out:
# numpy.ndarray
