# %%
import requests
import numpy as np
import random
from shapely.geometry import Polygon, Point
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import PIL
import os
import glob

# %% [markdown]
# # Getting 306 negative samples

# %%
#defining the desired polygon
poly = Polygon([(21.918040918535297, 89.06305835052626), (24.252438622786784, 88.70050952240126), (24.63250233706533, 88.00837085052626),
(25.19049184807116, 88.96418139740126), (25.81518675863702, 88.07428881927626), (26.42676629560675, 88.46979663177626),
(24.996478568131987, 90.14521167083876), (24.891882698398376, 92.50177905365126), (24.00679268283591, 91.25483081146376),
(23.00669873788841, 91.31626408848514), (22.89541581465374, 91.73374455723514), (23.591938738838373, 92.16221135411014),
(21.52233752876157, 92.56870549473514), (23.253067895585048, 90.54122371950571) ])

# %%
#defining the randomizer function using npy

def polygon_random_points (poly, num_points):
    min_x, min_y, max_x, max_y = poly.bounds
    
    points = []

    while len(points) < num_points:
        random_point = Point([random.uniform(min_x, max_x), random.uniform(min_y, max_y)])
        if (random_point.within(poly)):
            points.append(random_point)

    return points

# %%
#choosing the number of points desired
points = polygon_random_points(poly,80)

# %%
#printing the results
for p in points:
    center = '%s,%s' % (p.x, p.y)
    print(center)
# Out:
# 23.882503821194895,88.85872712591966
# 22.447478482746046,89.4773971818952
# 24.939998896989767,88.73612947635547
# 22.966515586701938,88.93058536260536
# 23.82759723150992,91.22482529565488
# 22.81269938993291,89.9049890619631
# 22.59355776533677,91.67788537135276
# 24.023102839617373,90.959898876355
# 23.27463896118021,90.55248068003685
# 24.600971157502727,89.68400000061891
# 23.179027572142555,90.7434010733608
# 25.3979782309433,88.88792679330095
# 23.558117847708917,89.25761575796916
# 23.36153804572616,91.21644374178862
# 23.272406354772322,90.19334621814772
# 25.42327763694614,89.49375992759362
# 23.69074091834243,91.21653647426429
# 24.304021381414767,90.33457558275092
# 23.123849961701914,92.02711515724451
# 25.034541231094362,89.46117854261026
# 23.109101308543842,89.55064594170385
# 23.124137956779514,89.95633632771666
# 25.777880506954855,88.22875470799285
# 24.26629482652924,89.53104626371551
# 25.262886733806003,89.25518973997119
# 24.515809859837812,88.48681341723392
# ...

# %%
#fixed parameters
base_url = "https://maps.googleapis.com/maps/api/staticmap?"
zoom = "19"
size = "160x160"
maptype = "satellite"
key = "AIzaSyCaeQbWCB_E-2MU8py77TGySO4wMQ2XhUA"

# %%
#iterate through list and get an image from each lat-long pair
for p in points:
    center = '%s,%s' % (p.x, p.y)
    url = base_url + "center=" + center + "&zoom=" + zoom + "&size=" + size + "&maptype=" + maptype + "&key=" + key
    r = requests.get(url)
    with open('%s_160_zoom18.png' % center, 'wb') as file:
        file.write(r.content)

# %% [markdown]
# # Getting 306 positive samples

# %%
#coords for solar farms, parks, and installations in Bangladesh
#found via manual search in Google Maps

#list of coordinates
coordinates = [(23.78088,89.82532), (23.78113, 89.82296), (23.78364, 89.824), (23.77956, 89.82303), (23.77855, 89.82612), (23.77675, 89.82635), (24.38749, 89.7486), (24.38727, 89.74835), (24.38636, 89.74867), (24.38601, 89.74803), (24.38583, 89.74856), (24.38559, 89.74814), (24.38546, 89.74846), (24.38507, 89.7481), (24.38484, 89.7485), (24.38458, 89.74808), (23.7793, 90.41705), (23.77927, 90.41694), (23.93414, 89.72104), (23.93402, 89.72113), (23.93409, 89.72144), (23.93421, 89.
# %%
len(coordinates)
# Out:
# 306

# %%
#fixed parameters
base_url = "https://maps.googleapis.com/maps/api/staticmap?"
zoom = "19"
size = "160x160"
maptype = "satellite"
key = "AIzaSyCaeQbWCB_E-2MU8py77TGySO4wMQ2XhUA"

# %%
#printing the results
for p in coordinates:
    center = '%s,%s' % (p[0], p[1])
    print(center)
# Out:
# 23.78088,89.82532
# 23.78113,89.82296
# 23.78364,89.824
# 23.77956,89.82303
# 23.77855,89.82612
# 23.77675,89.82635
# 24.38749,89.7486
# 24.38727,89.74835
# 24.38636,89.74867
# 24.38601,89.74803
# 24.38583,89.74856
# 24.38559,89.74814
# 24.38546,89.74846
# 24.38507,89.7481
# 24.38484,89.7485
# 24.38458,89.74808
# 23.7793,90.41705
# 23.77927,90.41694
# 23.93414,89.72104
# 23.93402,89.72113
# 23.93409,89.72144
# 23.93421,89.72133
# 24.773,89.84189
# 24.77299,89.84231
# 24.77278,89.8419
# 24.77274,89.8423
# 24.77246,89.84185
# 24.77258,89.84215
# 24.77259,89.84259
# 24.77236,89.84211
# 24.77226,89.8418
# 24.77254,89.84314
# 24.77241,89.84245
# 24.77215,89.84194
# 24.77188,89.84218
# 24.77215,89.84253
# 24.77186,89.84298
# 24.77228,89.84328
# 24.77215,89.84291
# 24.1223,88.74832
# 24.12223,88.74833
# 24.12216,88.74827
# 24.1221,88.74829
# 24.12225,88.7486
# 24.12216,88.74866
# 24.1221,88.74862
# 24.12203,88.74861
# 24.70598,90.45562
# 24.70623,90.45669
# 24.70577,90.4563
# ...

# %%
#iterate through list and get an image from each lat-long pair
for p in coordinates:
    center = '%s,%s' % (p[0], p[1])
    url = base_url + "center=" + center + "&zoom=" + zoom + "&size=" + size + "&maptype=" + maptype + "&key=" + key
    r = requests.get(url)
    with open('%s.png' % center, 'wb') as file:
        file.write(r.content)

# %% [markdown]
# # Getting original paper's 100 positive samples and 100 negative samples

# %%
data = pd.read_csv('DeepSolar_eval_set_coordinates_and_labels.csv')

# %%
negative_samples = data[data['label']==0]
positive_samples = data[data['label']==1]

# %%
positive_samples
# Out:
#              lat         lon  label
# 476    33.696801 -117.853567      1
# 731    33.696237 -117.854121      1
# 907    33.678254 -117.844077      1
# 965    33.686260 -117.844230      1
# 1089   33.851120 -118.315144      1
# ...          ...         ...    ...
# 90562  30.373723  -97.719905      1
# 90654  30.399082  -97.718519      1
# 90694  30.376718  -97.727793      1
# 90951  30.398916  -97.718562      1
# 91186  30.390689  -97.726066      1
#
# [1221 rows x 3 columns]

# %%
negative_samples
# Out:
#              lat         lon  label
# 0      33.681309 -117.842689      0
# 1      33.696072 -117.865912      0
# 2      33.680925 -117.854539      0
# 3      33.676544 -117.844537      0
# 4      33.700084 -117.866494      0
# ...          ...         ...    ...
# 93495  43.095805  -87.973643      0
# 93496  43.097172  -87.972811      0
# 93497  43.097189  -87.988451      0
# 93498  43.094683  -87.994667      0
# 93499  43.105207  -87.997773      0
#
# [92279 rows x 3 columns]

# %%
positive_samples = positive_samples.sample(n=100)
negative_samples = negative_samples.sample(n=100)

# %%
positive_samples = positive_samples.reset_index()
negative_samples = negative_samples.reset_index()

# %%
for ind in positive_samples.index:
    print(positive_samples['lat'][ind], positive_samples['lon'][ind])
# Out:
# 35.04991560988917 -106.61646175202284
# 33.696801098357994 -117.8535666896372
# 34.23026740913345 -118.5215803969568
# 40.68817809476139 -74.29822421771091
# 44.03260622647346 -123.1030050567178
# 36.80177288276698 -119.7630877685973
# 40.01810241575617 -105.25669415178072
# 40.02393705015775 -105.2478634288168
# 36.79151606640493 -119.8050104955244
# 42.372601244682606 -71.1362073188589
# 42.39989626930077 -71.14332267784003
# 44.03236290488833 -123.0986626958311
# 40.73703000975624 -74.21043183263822
# 36.22440833638757 -115.23355221463964
# 36.20579264425562 -115.2335616444218
# 34.07854576923107 -117.63614001515468
# 40.70756188298909 -74.25841578193939
# 36.80625212760726 -119.77740966873316
# 33.849216805655395 -118.2959483650375
# 44.02958484410506 -123.11541389296973
# 42.39239884090552 -71.13569130174824
# 33.8516287999572 -118.31118134047642
# 36.78275426483805 -119.77729897648712
# 34.088631865662514 -117.44343164654882
# 45.51564668792495 -122.62988514347664
# ...

# %%
for ind in negative_samples.index:
    print(negative_samples['lat'][ind], negative_samples['lon'][ind])
# Out:
# 35.126941424014404 -106.5625641021428
# 25.808150840992543 -80.21907727163003
# 34.21696537377643 -118.5172166922502
# 33.690419457904326 -117.8650521295128
# 35.11716602724848 -106.5419470513924
# 40.71726082318073 -74.28858681482478
# 42.39102842309093 -71.13313255136111
# 40.675319792953225 -111.9029811050148
# 45.51548345604583 -122.61832227637548
# 36.20845393990593 -115.2106878888506
# 38.93759547301868 -77.02690081829503
# 33.4989450730665 -112.18696643944836
# 40.74219218635592 -74.19400477387545
# 40.70778540682313 -74.26548321160136
# 42.41335490525516 -71.14139262033052
# 38.66623433024064 -90.24517414585044
# 34.21208632409725 -118.53548055974528
# 35.11307879212792 -106.52722073177142
# 35.11626872175179 -106.55195559719392
# 40.50356505915399 -74.40328576569564
# 44.05113204871328 -123.15487555531706
# 36.7882792220388 -119.81395487655227
# 38.66723155550334 -90.23418350752468
# 40.73777884101148 -74.2116040078681
# 35.11514282371012 -106.55236926034124
# ...

# %%
for ind in positive_samples.index:
    center = '%s,%s' % (positive_samples['lat'][ind], positive_samples['lon'][ind])
    url = base_url + "center=" + center + "&zoom=" + zoom + "&size=" + size + "&maptype=" + maptype + "&key=" + key
    r = requests.get(url)
    with open('%s.png' % center, 'wb') as file:
        file.write(r.content)
# Out:
# 35.04991560988917,-106.61646175202284
# 33.696801098357994,-117.8535666896372
# 34.23026740913345,-118.5215803969568
# 40.68817809476139,-74.29822421771091
# 44.03260622647346,-123.1030050567178
# 36.80177288276698,-119.7630877685973
# 40.01810241575617,-105.25669415178072
# 40.02393705015775,-105.2478634288168
# 36.79151606640493,-119.8050104955244
# 42.372601244682606,-71.1362073188589
# 42.39989626930077,-71.14332267784003
# 44.03236290488833,-123.0986626958311
# 40.73703000975624,-74.21043183263822
# 36.22440833638757,-115.23355221463964
# 36.20579264425562,-115.2335616444218
# 34.07854576923107,-117.63614001515468
# 40.70756188298909,-74.25841578193939
# 36.80625212760726,-119.77740966873316
# 33.849216805655395,-118.2959483650375
# 44.02958484410506,-123.11541389296973
# 42.39239884090552,-71.13569130174824
# 33.8516287999572,-118.31118134047642
# 36.78275426483805,-119.77729897648712
# 34.088631865662514,-117.44343164654882
# 45.51564668792495,-122.62988514347664
# ...

# %%
for ind in negative_samples.index:
    center = '%s,%s' % (negative_samples['lat'][ind], negative_samples['lon'][ind])
    url = base_url + "center=" + center + "&zoom=" + zoom + "&size=" + size + "&maptype=" + maptype + "&key=" + key
    r = requests.get(url)
    with open('%s.png' % center, 'wb') as file:
        file.write(r.content)

# %% [markdown]
# # Creating final image dataset

# %%
test_set = pd.DataFrame(columns=['image', 'class'])
images_list = []
class_list = []
img_path_list = []

# %%
negative_sample_files = os.listdir('/Users/farihahahmed/Documents/deepsolar/test_ds/0')
positive_sample_files = os.listdir('/Users/farihahahmed/Documents/deepsolar/test_ds/1')

# %%
for i in positive_sample_files:
    image = mpimg.imread('/Users/farihahahmed/Documents/deepsolar/test_ds/1/%s' %(i))
    images_list.append(image)
    class_list.append(1)

# %%
for i in negative_sample_files:
    image = mpimg.imread('/Users/farihahahmed/Documents/deepsolar/test_ds/0/%s' %(i))
    images_list.append(image)
    class_list.append(0)

# %%
print(len(images_list))
print(len(class_list))
# Out:
# 200
# 200

# %%
test_set['image'] = images_list
test_set['class'] = class_list

# %%
test_set.head()
# Out:
#                                                image  class
# 0  [[[0.9882353, 1.0, 1.0, 1.0], [0.9764706, 1.0,...      1
# 1  [[[0.85490197, 0.8862745, 0.89411765, 1.0], [0...      1
# 2  [[[0.26666668, 0.26666668, 0.33333334, 1.0], [...      1
# 3  [[[0.36078432, 0.38039216, 0.38039216, 1.0], [...      1
# 4  [[[0.26666668, 0.26666668, 0.26666668, 1.0], [...      1

# %%
test_set.to_pickle("test_set_ds.pkl")

# %%
check_df = pd.read_pickle("test_set.pkl")

# %%
check_df
# Out:
#                                                  image  class
# 0    [[[0.3137255, 0.40784314, 0.5058824, 1.0], [0....      1
# 1    [[[0.43137255, 0.41568628, 0.41568628, 1.0], [...      1
# 2    [[[0.25882354, 0.28235295, 0.36078432, 1.0], [...      1
# 3    [[[0.39607844, 0.41568628, 0.42745098, 1.0], [...      1
# 4    [[[0.3764706, 0.4627451, 0.5529412, 1.0], [0.3...      1
# ..                                                 ...    ...
# 607  [[[0.6117647, 0.5372549, 0.5254902, 1.0], [0.6...      0
# 608  [[[0.7019608, 0.6392157, 0.5529412, 1.0], [0.7...      0
# 609  [[[0.05490196, 0.09019608, 0.08627451, 1.0], [...      0
# 610  [[[0.3882353, 0.38431373, 0.34901962, 1.0], [0...      0
# 611  [[[0.21568628, 0.25490198, 0.20392157, 1.0], [...      0
#
# [612 rows x 2 columns]

# %% [markdown]
# # Code I'm not using anymore

# %%
# Np Meshgrid

## long_coords = i coords (x), and lat_coords = j coords (y)

lat_start = 24.25956
lat_stop = 23.34481
lat_step = -0.0003816123937

long_start = 89.91236
long_stop = 90.91985
long_step = 0.0004231184771

lat_range = np.arange(lat_start, lat_stop, lat_step)
long_range = np.arange(long_start, long_stop, long_step)

#creating meshgrid 
long_coords, lat_coords = np.meshgrid(long_range, lat_range, indexing='ij')

#reshaping data to be 1-dimensional
long_coords_flat = long_coords.reshape(-1)
lat_coords_flat = lat_coords.reshape(-1)

coord_list = list(zip(long_coords_flat, lat_coords_flat))
